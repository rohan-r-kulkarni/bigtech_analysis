# %%
import pandas as pd
from pandas_datareader import data, wb
import numpy as np
import requests
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# <h1> Data Processing </h1>

# %% [markdown]
# We obtained the price and fundamentals data for each stock we consider (META, GOOG, AMZN, NFLX, TSLA) from a Bloomberg terminal, which we then saved in a csv file.

# %%
url= "https://raw.githubusercontent.com/rohan-r-kulkarni/bigtech_randomforest/main/stockData.csv"
df = pd.read_csv(url)
df1=df.reset_index()
df1
# Out:
#       index Unnamed: 0 META US Equity   META US Equity.1 META US Equity.2  \
# 0         0        NaN              1                  2                3
# 1         1      Dates        PX_OPEN  PX_OFFICIAL_CLOSE         PE_RATIO
# 2         2     1/3/00            NaN                NaN              NaN
# 3         3     1/4/00            NaN                NaN              NaN
# 4         4     1/5/00            NaN                NaN              NaN
# ...     ...        ...            ...                ...              ...
# 5977   5977   11/28/22         109.54             109.46          10.3163
# 5978   5978   11/29/22        109.505              118.1          11.1306
# 5979   5979   11/30/22        119.198             120.44          11.3512
# 5980   5980    12/1/22         117.83             120.44          11.6386
# 5981   5981    12/2/22            NaN                NaN              NaN
#
#         META US Equity.3 META US Equity.4 META US Equity.5 META US Equity.6  \
# 0                      4                5                6                7
# 1     EV_EBITDA_ADJUSTED     SALES_GROWTH      CUR_MKT_CAP        PX_VOLUME
# 2                    NaN              NaN              NaN              NaN
# 3                    NaN              NaN              NaN              NaN
# 4                    NaN              NaN              NaN              NaN
# ...                  ...              ...              ...              ...
# 5977              7.5916          -4.4674      290238.5179         23899238
# 5978              7.5916          -4.4674      313147.8984         43348557
# 5979              7.5916          -4.4674      319352.5223         36551374
# 5980              7.5916          -4.4674      327439.7401         39685113
# 5981                 NaN              NaN              NaN              NaN
#
#           META US Equity.7  ...        SPX Index.1 SPX Index.2  \
# 0                        8  ...                  2           3
# 1     FREE_CASH_FLOW_YIELD  ...  PX_OFFICIAL_CLOSE    PE_RATIO
# 2                      NaN  ...                NaN     28.1209
# 3                      NaN  ...                NaN     28.1744
# 4                      NaN  ...                NaN     28.2119
# ...                    ...  ...                ...         ...
# 5977                8.7726  ...                NaN     19.1332
# 5978                8.1308  ...                NaN     19.7254
# 5979                7.9728  ...                NaN     19.7083
# 5980                7.7759  ...                NaN     19.6847
# 5981                   NaN  ...                NaN         NaN
#
#              SPX Index.3   SPX Index.4  SPX Index.5 SPX Index.6  \
# 0                      4             5            6           7
# 1     EV_EBITDA_ADJUSTED  SALES_GROWTH  CUR_MKT_CAP   PX_VOLUME
# 2                    NaN           NaN          NaN  1071554100
# 3                    NaN           NaN          NaN  1264023700
# 4                    NaN           NaN          NaN  1177726200
# ...                  ...           ...          ...         ...
# 5977                 NaN           NaN  34556774.68   517449991
# 5978                 NaN           NaN  35624829.34  1406250061
# 5979                 NaN           NaN  35596739.87   633969105
# 5980                 NaN           NaN  35596739.87   633969105
# 5981                 NaN           NaN          NaN         NaN
#
#                SPX Index.7  SPX Index.8        SPX Index.9  \
# 0                        8            9                 10
# 1     FREE_CASH_FLOW_YIELD  PROF_MARGIN  EBITDA_TO_REVENUE
# 2                     2.99         7.61                NaN
# 3                     2.99         7.61                NaN
# 4                     2.98         7.61                NaN
# ...                    ...          ...                ...
# 5977                  4.95        11.17                NaN
# 5978                   4.8        11.17                NaN
# 5979                   4.8        11.17                NaN
# 5980                  4.81        11.17                NaN
# 5981                   NaN          NaN                NaN
#
#              SPX Index.10
# 0                      11
# 1     BEST_PX_SALES_RATIO
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 5977               2.2736
# 5978                2.343
# 5979               2.3389
# 5980                2.336
# 5981                  NaN
#
# [5982 rows x 68 columns]

# %%
df2=df1.rename(columns={"Unnamed: 0": "Dates"})
dates=df2.loc[2:, "Dates"].reset_index(drop=True)
dates=pd.to_datetime(dates)

# %% [markdown]
# <h2> Get S&P 500 Price Series </h2>

# %% [markdown]
# We could use this as a baseline to compare our model with after it is trained. Here for completeness.

# %%
spx_i = 5
spx_df = pd.DataFrame(df2.iloc[1: , 2+11*spx_i:].reset_index(drop=True))
spx_df.columns = spx_df.iloc[0, :]
#spx_df.columns = spx_df.loc[1, :]
spx_df = pd.DataFrame(spx_df.iloc[1:, 0]).reset_index(drop=True).dropna() #column 0 is the PX_OPEN price
spx_df
# Out:
#       PX_OPEN
# 0     1455.22
# 1     1399.42
# 2     1402.11
# 3     1403.45
# 4     1441.47
# ...       ...
# 5974  4005.36
# 5975  3964.19
# 5976  3957.18
# 5977  4087.14
# 5978  4040.17
#
# [5979 rows x 1 columns]

# %% [markdown]
# <h2> Get Big Tech Stocks and Metrics </h2>

# %% [markdown]
# Here we clean and format the raw dataframe to separate out the individual stock data. We utilize the Yahoo Finance API to pull more data by date, such as the High, Low, and Adjusted Close. This is joined with the existing Bloomberg data. We also generate a buy_indicator (BUY is 1, NOT BUY is 0) that will be our actual output vector during learning.
#
# Additionally, we must shift the buy indicator for our price series by 1 because the metrics that we train on for one day evaluate our strategy (BUY or NOT BUY) for the next day. We cannot make a BUY or NOT BUY indication for the same day, because the day is already over! This will avoid a corrupted model.

# %%
stocks = {} #save cleaned stock dfs in a dictionary with the keys being the stock tickers 
drop = ["SALES_GROWTH", "PROF_MARGIN", "EBITDA_TO_REVENUE","EV_EBITDA_ADJUSTED"] #fundamentals are not considered
names = [] #stock names

for i in range(0, 5):
    this_name = df2.columns[2+11*i].split(" ")[0]

    this_df = df2.iloc[1: , 2+11*i:13+11*i].reset_index(drop=True)
    this_df.columns = this_df.loc[0, :]
    this_df = this_df.drop(drop, axis = 1)
    this_df = this_df.loc[1:, :].reset_index(drop=True)
    this_df = pd.concat([dates, this_df], axis=1)

    this_df = this_df.reindex(['Dates', 'PX_OPEN', 'PE_RATIO', 'CUR_MKT_CAP',
        'PX_VOLUME', 'FREE_CASH_FLOW_YIELD', 'BEST_PX_SALES_RATIO','PX_OFFICIAL_CLOSE'],axis=1)
    
    this_df=this_df.set_index("Dates")
    this_df=this_df.astype(float)

    #convert dates to datetime object type to format as ""%Y-%m-%d"
    start_date = pd.to_datetime(this_df.index)[0]
    end_date = pd.to_datetime(this_df.index)[-1]
    
    start_date = start_date.strftime("%Y-%m-%d")
    end_date = end_date.strftime("%Y-%m-%d")

    
    yf_data = yf.download(this_name, start=start_date, end=end_date)
    yf_data = yf_data.loc[:, ["High", "Low", "Adj Close"]]
    
    yf_data = yf_data.rename({"High": "HIGH", "Low":"LOW", "Adj Close": "ADJ_CLOSE"}, axis=1)
    
    this_df = this_df.join(yf_data)
    
    #price series shifts
    #accomodate that the action (BUY or NOT BUY) for training on a given day can only be executed the next day
        
    day_change = this_df.loc[:,"ADJ_CLOSE"] - this_df.loc[:,"PX_OPEN"] #close - open
    
    buy_indicator = (day_change>0).astype(int).shift(1) #the actual y value (BUY or NOT BUY), shifted
    this_df=this_df.assign(day_change=day_change)
    this_df=this_df.assign(buy_indicator=buy_indicator)
    
    this_df['ADJ_CLOSE']=this_df['ADJ_CLOSE'].shift(-1) #move the ADJ_CLOSE to the correct date (API fix)

    if len(this_df) < 500: # do not include stocks with too small length for training
        continue 
    
    names.append(this_name)

    stocks[this_name] = this_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stocks
# Out:
# {'META':             PX_OPEN  PE_RATIO  CUR_MKT_CAP   PX_VOLUME  FREE_CASH_FLOW_YIELD  \
#  Dates
#  2000-01-03      NaN       NaN          NaN         NaN                   NaN
#  2000-01-04      NaN       NaN          NaN         NaN                   NaN
#  2000-01-05      NaN       NaN          NaN         NaN                   NaN
#  2000-01-06      NaN       NaN          NaN         NaN                   NaN
#  2000-01-07      NaN       NaN          NaN         NaN                   NaN
#  ...             ...       ...          ...         ...                   ...
#  2022-11-28  109.540   10.3163  290238.5179  23899238.0                8.7726
#  2022-11-29  109.505   11.1306  313147.8984  43348557.0                8.1308
#  2022-11-30  119.198   11.3512  319352.5223  36551374.0                7.9728
#  2022-12-01  117.830   11.6386  327439.7401  39685113.0                7.7759
#  2022-12-02      NaN       NaN          NaN         NaN                   NaN
#
#              BEST_PX_SALES_RATIO  PX_OFFICIAL_CLOSE        HIGH         LOW  \
#  Dates
#  2000-01-03                  NaN                NaN         NaN         NaN
#  2000-01-04                  NaN                NaN         NaN         NaN
#  2000-01-05                  NaN                NaN         NaN         NaN
#  2000-01-06                  NaN                NaN         NaN         NaN
#  2000-01-07                  NaN                NaN         NaN         NaN
#  ...                         ...                ...         ...         ...
#  2022-11-28                2.457             109.46  112.040001  108.379997
#  2022-11-29                2.651             118.10  110.940002  108.540001
#  2022-11-30                2.703             120.44  118.160004  109.379997
#  2022-12-01                2.772             120.44  121.199997  118.400002
#  2022-12-02                  NaN                NaN         NaN         NaN
#
#               ADJ_CLOSE  day_change  buy_indicator
#  Dates
#  2000-01-03         NaN         NaN            NaN
#  2000-01-04         NaN         NaN            0.0
#  2000-01-05         NaN         NaN            0.0
#  2000-01-06         NaN         NaN            0.0
#  2000-01-07         NaN         NaN            0.0
#  ...                ...         ...            ...
#  2022-11-28  109.459999   -0.760001            1.0
#  2022-11-29  118.099998   -0.045001            0.0
#  2022-11-30  120.440002   -1.098002            0.0
#  2022-12-01         NaN    2.610002            0.0
#  2022-12-02         NaN         NaN            1.0
#
#  [5980 rows x 12 columns],
#  'GOOG':             PX_OPEN  PE_RATIO  CUR_MKT_CAP   PX_VOLUME  FREE_CASH_FLOW_YIELD  \
#  Dates
#  2000-01-03      NaN       NaN          NaN         NaN                   NaN
#  2000-01-04      NaN       NaN          NaN         NaN                   NaN
#  2000-01-05      NaN       NaN          NaN         NaN                   NaN
#  2000-01-06      NaN       NaN          NaN         NaN                   NaN
#  2000-01-07      NaN       NaN          NaN         NaN                   NaN
#  ...             ...       ...          ...         ...                   ...
#  2022-11-28    96.00       NaN  1233676.170  20220007.0                   NaN
#  2022-11-29    95.12       NaN  1310116.450  39888074.0                   NaN
#  2022-11-30   101.40       NaN  1309006.690  21771536.0                   NaN
#  2022-12-01    99.37       NaN  1302540.868  17410375.0                   NaN
#  2022-12-02      NaN       NaN          NaN         NaN                   NaN
#
#              BEST_PX_SALES_RATIO  PX_OFFICIAL_CLOSE        HIGH         LOW  \
#  Dates
#  2000-01-03                  NaN                NaN         NaN         NaN
#  2000-01-04                  NaN                NaN         NaN         NaN
#  2000-01-05                  NaN                NaN         NaN         NaN
#  2000-01-06                  NaN                NaN         NaN         NaN
#  2000-01-07                  NaN                NaN         NaN         NaN
#  ...                         ...                ...         ...         ...
#  2022-11-28                4.921              95.44   97.830002   95.889999
#  2022-11-29                5.268             101.45   96.389999   94.389999
#  2022-11-30                5.264             101.28  101.449997   94.669998
#  2022-12-01                5.238             101.28  102.589996  100.669998
#  2022-12-02                  NaN                NaN         NaN         NaN
#
#               ADJ_CLOSE  day_change  buy_indicator
#  Dates
#  2000-01-03         NaN         NaN            NaN
#  2000-01-04         NaN         NaN            0.0
#  2000-01-05         NaN         NaN            0.0
#  2000-01-06         NaN         NaN            0.0
#  2000-01-07         NaN         NaN            0.0
#  ...                ...         ...            ...
#  2022-11-28   95.440002    0.250000            1.0
#  2022-11-29  101.449997    0.320002            1.0
#  2022-11-30  101.279999    0.049997            1.0
#  2022-12-01         NaN    1.909999            1.0
#  2022-12-02         NaN         NaN            1.0
#
#  [5980 rows x 12 columns],
#  'AMZN':             PX_OPEN  PE_RATIO  CUR_MKT_CAP    PX_VOLUME  FREE_CASH_FLOW_YIELD  \
#  Dates
#  2000-01-03    4.269       NaN   27923.2338  349586000.0               -1.4045
#  2000-01-04    3.525       NaN   23769.8924  769162000.0               -1.6499
#  2000-01-05    3.566       NaN   22342.8469  375100000.0               -1.7553
#  2000-01-06    3.350       NaN   23705.9948  210108000.0               -1.6544
#  2000-01-07    3.628       NaN   23578.1997  295168000.0               -1.6633
#  ...             ...       ...          ...          ...                   ...
#  2022-11-28   94.040   92.8153  942836.8789   65567286.0               -2.7970
#  2022-11-29   92.470   96.9529  984867.6942  102805806.0               -2.6776
#  2022-11-30   96.990   95.9084  974257.9738   68487969.0               -2.7067
#  2022-12-01   94.475   94.5326  960281.6796   70409267.0               -2.7461
#  2022-12-02      NaN       NaN          NaN          NaN                   NaN
#
#              BEST_PX_SALES_RATIO  PX_OFFICIAL_CLOSE       HIGH        LOW  \
#  Dates
#  2000-01-03                  NaN                NaN   4.478125   3.952344
#  2000-01-04                  NaN                NaN   4.575000   4.087500
#  2000-01-05                  NaN                NaN   3.756250   3.400000
#  2000-01-06                  NaN                NaN   3.634375   3.200000
#  2000-01-07                  NaN                NaN   3.525000   3.309375
#  ...                         ...                ...        ...        ...
#  2022-11-28                1.728              92.42  96.400002  93.430000
#  2022-11-29                1.805              96.54  94.410004  91.440002
#  2022-11-30                1.786              95.50  96.540001  91.529999
#  2022-12-01                1.760              95.50  97.230003  94.919998
#  2022-12-02                  NaN                NaN        NaN        NaN
#
#              ADJ_CLOSE  day_change  buy_indicator
#  Dates
#  2000-01-03   4.096875    0.199750            NaN
#  2000-01-04   3.487500    0.571875            1.0
#  2000-01-05   3.278125   -0.078500            1.0
#  2000-01-06   3.478125   -0.071875            0.0
#  2000-01-07   3.459375   -0.149875            0.0
#  ...               ...         ...            ...
#  2022-11-28  92.419998   -0.090003            0.0
#  2022-11-29  96.540001   -0.050002            0.0
#  2022-11-30  95.500000   -0.449999            0.0
#  2022-12-01        NaN    1.025000            0.0
#  2022-12-02        NaN         NaN            1.0
#
#  [5980 rows x 12 columns],
#  'NFLX':             PX_OPEN  PE_RATIO  CUR_MKT_CAP   PX_VOLUME  FREE_CASH_FLOW_YIELD  \
#  Dates
#  2000-01-03      NaN       NaN          NaN         NaN                   NaN
#  2000-01-04      NaN       NaN          NaN         NaN                   NaN
#  2000-01-05      NaN       NaN          NaN         NaN                   NaN
#  2000-01-06      NaN       NaN          NaN         NaN                   NaN
#  2000-01-07      NaN       NaN          NaN         NaN                   NaN
#  ...             ...       ...          ...         ...                   ...
#  2022-11-28   282.50   29.3236  125032.9580   5786874.0                0.5733
#  2022-11-29   281.37   31.8880  135967.1115  16070120.0                0.5272
#  2022-11-30   303.99   33.0799  141049.2456  14664866.0                0.5082
#  2022-12-01   310.49   33.4410  142589.0181  12633736.0                0.5027
#  2022-12-02      NaN       NaN          NaN         NaN                   NaN
#
#              BEST_PX_SALES_RATIO  PX_OFFICIAL_CLOSE        HIGH         LOW  \
#  Dates
#  2000-01-03                  NaN                NaN         NaN         NaN
#  2000-01-04                  NaN                NaN         NaN         NaN
#  2000-01-05                  NaN                NaN         NaN         NaN
#  2000-01-06                  NaN                NaN         NaN         NaN
#  2000-01-07                  NaN                NaN         NaN         NaN
#  ...                         ...                ...         ...         ...
#  2022-11-28                3.777             280.96  289.549988  280.529999
#  2022-11-29                4.107             305.53  282.959991  275.940002
#  2022-11-30                4.261             316.95  308.260010  280.410004
#  2022-12-01                4.307             316.95  319.799988  303.029999
#  2022-12-02                  NaN                NaN         NaN         NaN
#
#               ADJ_CLOSE  day_change  buy_indicator
#  Dates
#  2000-01-03         NaN         NaN            NaN
#  2000-01-04         NaN         NaN            0.0
#  2000-01-05         NaN         NaN            0.0
#  2000-01-06         NaN         NaN            0.0
#  2000-01-07         NaN         NaN            0.0
#  ...                ...         ...            ...
#  2022-11-28  280.959991   -1.329987            1.0
#  2022-11-29  305.529999   -0.410009            0.0
#  2022-11-30  316.950012    1.539999            0.0
#  2022-12-01         NaN    6.460012            1.0
#  2022-12-02         NaN         NaN            1.0
#
#  [5980 rows x 12 columns],
#  'TSLA':             PX_OPEN  PE_RATIO  CUR_MKT_CAP    PX_VOLUME  FREE_CASH_FLOW_YIELD  \
#  Dates
#  2000-01-03      NaN       NaN          NaN          NaN                   NaN
#  2000-01-04      NaN       NaN          NaN          NaN                   NaN
#  2000-01-05      NaN       NaN          NaN          NaN                   NaN
#  2000-01-06      NaN       NaN          NaN          NaN                   NaN
#  2000-01-07      NaN       NaN          NaN          NaN                   NaN
#  ...             ...       ...          ...          ...                   ...
#  2022-11-28   184.99   55.3159  571016.3754   83357111.0                1.5911
#  2022-11-29   182.43   59.5587  614814.4018  109186404.0                1.4778
#  2022-11-30   197.08   59.5587  614814.4018   80046213.0                1.4778
#  2022-12-01   191.78   59.6077  615319.6441   73262812.0                1.4765
#  2022-12-02      NaN       NaN          NaN          NaN                   NaN
#
#              BEST_PX_SALES_RATIO  PX_OFFICIAL_CLOSE        HIGH         LOW  \
#  Dates
#  2000-01-03                  NaN                NaN         NaN         NaN
#  2000-01-04                  NaN                NaN         NaN         NaN
#  2000-01-05                  NaN                NaN         NaN         NaN
#  2000-01-06                  NaN                NaN         NaN         NaN
#  2000-01-07                  NaN                NaN         NaN         NaN
#  ...                         ...                ...         ...         ...
#  2022-11-28                5.141             180.83  188.500000  179.000000
#  2022-11-29                5.536             194.70  186.380005  178.750000
#  2022-11-30                5.537             194.70  194.759995  180.630005
#  2022-12-01                5.541             194.70  198.919998  191.800003
#  2022-12-02                  NaN                NaN         NaN         NaN
#
#               ADJ_CLOSE  day_change  buy_indicator
#  Dates
#  2000-01-03         NaN         NaN            NaN
#  2000-01-04         NaN         NaN            0.0
#  2000-01-05         NaN         NaN            0.0
#  2000-01-06         NaN         NaN            0.0
#  2000-01-07         NaN         NaN            0.0
#  ...                ...         ...            ...
#  2022-11-28  180.830002   -2.070002            1.0
#  2022-11-29  194.699997   -1.599998            0.0
#  2022-11-30  194.699997   -2.380003            0.0
#  2022-12-01         NaN    2.919997            0.0
#  2022-12-02         NaN         NaN            1.0
#
#  [5980 rows x 12 columns]}

# %%
names
# Out:
# ['META', 'GOOG', 'AMZN', 'NFLX', 'TSLA']

# %% [markdown]
# <h1> Implementing Technical Indicators </h1>

# %% [markdown]
# We implement 6 technical indicators: On-Balance Volume (OBV), Bollinger Band, Moving Average Convergence Divergence (MACD), Volume Weighted Average Price (VWAP), Relative Strength Index (RSI), and Money Flow Index (MFI). There are all calculations done with the price series and other fundamentals such as volume. The BUY or NOT BUY indications are also shifted by 1 for the same reason as the shift for the price series above.
#
# For a technical indicator `X`, there is a `get_X(s)` function that calculates and assigns the indicator `X` as a column in the stock `s`'s dataframe. The `get_X(s)` may call a helper function `calc_X(x)` which can be used with the `apply()` method along a DataFrame. Some indicators also have an implementation for `plot_X(X_df)` which utilizes the DataFrame made in `get_X(s)` to plot the individual technical indicator's returns. This `plot_X(X_df)` function was used by us during development to determine which technical indicators we should include to train on our model.

# %% [markdown]
# <h3>1. On-Balance Volume (OBV) </h3>

# %% [markdown]
# This indicator predicts future prices using volume. The theory is that when volume increases, price will follow. It is meant to quantify sentiment in market activity.

# %%
def calc_obv(x):
    #formulaic definition of OBV
    if x.ADJ_CLOSE > x.prev_close:
        return x.prev_vol + x.PX_VOLUME
    elif x.ADJ_CLOSE < x.prev_close:
        return x.prev_vol - x.PX_VOLUME
    else:
        return x.prev_vol

# %%
def get_obv(s):
    obv = stocks[s].copy().loc[:, ["PX_VOLUME", "ADJ_CLOSE"]]
    obv=obv.assign(prev_close=obv.loc[:, "ADJ_CLOSE"].shift(1))
    vols=obv.loc[:, "PX_VOLUME"].shift(1)
    vols.values[0] = 0
    obv=obv.assign(prev_vol=vols)
    OBV_FIN=obv.apply(calc_obv, axis=1)
    obv=obv.assign(OBV_FIN=OBV_FIN)
    obv=obv.assign(close_change = obv.ADJ_CLOSE-obv.prev_close)
    obv=obv.assign(volume_change = obv.PX_VOLUME-obv.prev_vol)
    
    #strategy for BUY or NOT BUY given OBV
    obv_indicator = ((obv.OBV_FIN.diff() > 0) & (obv.close_change > 0)).astype(int).shift(1)

    stocks[s]=stocks[s].assign(OBV_indicator=obv_indicator)

# %% [markdown]
# <h3>2. Bollinger Band </h3>

# %% [markdown]
# We also compute Bollinger bands. The middle Bollinger band is the simple moving average, and the upper Bolinger band and lower Bollinger bands are standard deviations above and below the average respectively.

# %%
def get_bollinger(s):
    boll_df = stocks[s].copy()
    #Set number of days and standard deviations to use for rolling lookback period for Bollinger band calculation
    window = 10
    no_of_std = 2
    #Calculate rolling mean and standard deviation using number of days set above
    rolling_mean = boll_df['ADJ_CLOSE'].rolling(window).mean()
    rolling_std = boll_df['ADJ_CLOSE'].rolling(window).std()
    #create two new DataFrame columns to hold values of upper and lower Bollinger bands
    boll_df['Rolling Mean'] = rolling_mean
    boll_df['Bollinger High'] = rolling_mean + (rolling_std * no_of_std)
    boll_df['Bollinger Low'] = rolling_mean - (rolling_std * no_of_std)
    
    #strategy for BUY or NOT BUY given Bollinger
    boll_indicator = ((boll_df.ADJ_CLOSE > 0) & (boll_df['Bollinger Low'] > 0)).astype(int).shift(1)
    boll_df=boll_df.assign(Position=boll_indicator)
    
    stocks[s]=stocks[s].assign(Bollinger_indicator=boll_indicator)

# %%
def plot_bollinger(boll_df):
    #Forward fill our position column to replace the "None" values with the correct long/short positions to represent the "holding" of our position
    #forward through time
    boll_df['Position'].fillna(method='ffill',inplace=True)
    #Calculate the daily market return and multiply that by the position to determine strategy returns
    boll_df['Market Return'] = np.log(boll_df['ADJ_CLOSE'] / boll_df['ADJ_CLOSE'].shift(1))
    boll_df['Strategy Return'] = boll_df['Market Return'] * boll_df['Position'].shift(1)
    #Plot the strategy returns
    boll_df[['Strategy Return','Market Return']].cumsum().plot()

# %% [markdown]
# <h3>3. Moving Average Convergence/Divergence (MACD) </h3>

# %% [markdown]
# For the MACD technical indicator, we consider the short and long term moving averages and see whether they cross. We choose to use exponential moving average over 9/12/26 periods by-day for MACD as this is more consistent with the practical definition of the indicator. The `com` parameter is a smoothing rate that can be adjusted. We choose to smooth evenly over the entire period.

# %%
def get_macd(s):
    ema_12=stocks[s].loc[:, "ADJ_CLOSE"].ewm(min_periods=12, com=12-1).mean()
    ema_26=stocks[s].loc[:, "ADJ_CLOSE"].ewm(min_periods=26, com=26-1).mean()
    macd = ema_12-ema_26
    #the signal line is the 9-period exponential moving average over the MACD
    signal_line=macd.ewm(min_periods=9, com=9-1).mean()

    #strategy for BUY or NOT BUY given MACD
    macd_indicator = ((macd > signal_line)).astype(int).shift(1)
    
    stocks[s]=stocks[s].assign(MACD_indicator=macd_indicator)

# %% [markdown]
# <h3>4. Volume Weighted Average Price (VWAP)</h3>

# %% [markdown]
# This technical indicator gives a different insight on the pricing of a stock given the traded volume on that day and the price. It utilizes cumulative measures to compute this.

# %%
def calc_vwap(x):
    #formulaic definition of VWAP
    return (x.cum_tp * x.PX_VOLUME)/(x.cum_vol)

# %%
def get_vwap(s):
    vwap_df=stocks[s].copy().loc[:, ["HIGH", "LOW", "ADJ_CLOSE", "PX_VOLUME"]]
    typ_price=vwap_df.loc[:, ["HIGH", "LOW", "ADJ_CLOSE"]].mean(axis=1)
    vol = vwap_df.loc[:, ["PX_VOLUME"]]
    cum_tp = typ_price.cumsum()
    cum_vol=vol.cumsum()
    vwap_df = vwap_df.assign(cum_tp=cum_tp)
    vwap_df = vwap_df.assign(cum_vol=cum_vol)
    vwap_df=vwap_df.assign(VWAP=vwap_df.apply(calc_vwap, axis=1))
    
    #strategy for BUY or NOT BUY given VWAP
    vwap_indicator = ((vwap_df.ADJ_CLOSE < vwap_df.VWAP)).astype(int).shift(1)
    vwap_df=vwap_df.assign(VWAP_indicator=vwap_indicator)

    stocks[s]=stocks[s].assign(VWAP_indicator=vwap_indicator)

# %% [markdown]
# <h3>5. Relative Strength Index (RSI) </h3>

# %% [markdown]
# The Relative Strength index quantifies how much and how fast a price is changing to calculate whether something is over or undersold. We utilize a threshold value to determine BUY or NOT BUY, which can be adjusted.

# %%
def calc_rsi(df, periods = 14, ema = True):    
    close_delta = df['ADJ_CLOSE'].diff()
    # Make two series: one for lower closes and one for higher closes
    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)    
    if ema == True:
        # Use exponential moving average
        ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    else:
        # Use simple moving average
        ma_up = up.rolling(window = periods, adjust=False).mean()
        ma_down = down.rolling(window = periods, adjust=False).mean()        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

# %%
def get_rsi(s):
    rsi_df=stocks[s].copy()
    rsi_df['RSI'] = calc_rsi(rsi_df, periods = 7, ema = True)
    # Threshold for RSI
    max_size=60
    
    #strategy for BUY or NOT BUY given RSI
    rsi_indicator = ((rsi_df['RSI'] > max_size)).astype(int).shift(1)
    rsi_df=rsi_df.assign(RSI_buy_indicator=rsi_indicator)

    stocks[s]=stocks[s].assign(RSI_indicator=rsi_indicator)

# %%
def plot_rsi(rsi_df):
    #Forward fill our position column to replace the "None" values with the correct long/short positions to represent the "holding" of our position
    #forward through time
    rsi_df['RSI_buy_indicator'].fillna(method='ffill',inplace=True)
    #Calculate the daily market return and multiply that by the position to determine strategy returns
    rsi_df['Market Return'] = np.log(rsi_df['ADJ_CLOSE'] / rsi_df['ADJ_CLOSE'].shift(1))
    rsi_df['Strategy Return'] = rsi_df['Market Return'] * rsi_df['RSI_buy_indicator'].shift(1)
    #Plot the strategy returns
    rsi_df[['Strategy Return','Market Return']].cumsum().plot()

# %% [markdown]
# <h3>6. Money Flow Index (MFI) </h3>

# %% [markdown]
# This technical indicator is another way of using the volume and price data to determine whether an asset is overbought or oversold.

# %%
def gain(x):
    return ((x > 0) * x).sum()

def loss(x):
    return ((x < 0) * x).sum()

def calc_mfi(high, low, close, volume, n=14):
    #formulaic definition of MFI
    typical_price = (high + low + close)/3
    money_flow = typical_price * volume
    mf_sign = np.where(typical_price > typical_price.shift(1), 1, -1)
    signed_mf = money_flow * mf_sign
    mf_avg_gain = signed_mf.rolling(n).apply(gain, raw=True)
    mf_avg_loss = signed_mf.rolling(n).apply(loss, raw=True)
    return (100 - (100 / (1 + (mf_avg_gain / abs(mf_avg_loss))))).to_numpy()

# %%
def get_mfi(s):
    mfi_df=stocks[s].copy()
    mfi_df['MFI'] = calc_mfi(mfi_df['HIGH'], mfi_df['LOW'], mfi_df['PX_OFFICIAL_CLOSE'], mfi_df['PX_VOLUME'], 14)
    
    #strategy for BUY or NOT BUY given MFI
    mfi_indicator = ((mfi_df['MFI'] > 60)).astype(int).shift(1)
    mfi_df=mfi_df.assign(MFI_buy_indicator=mfi_indicator)

    stocks[s]=stocks[s].assign(MFI_indicator=mfi_indicator)

# %% [markdown]
# <h1> Build Independent/Dependent Variables For Each Stock </h1>

# %% [markdown]
# Our objective is to deliver a consolidated technical analysis of all the indicator signals using machine learning for a BUY (1) or NOT BUY (0) for the day. Then we can determine which technical indicators are more important features for learning and thus for the strategy.
#
# For our technical analysis, we dropped the fundamentals we obtained as we will train only on technical indicators as the independent variables. The fundamentals could be used to train a model, but our focus is a day-trading strategy so it is not as relevant. The dependent variable is the previously computed `buy_indicator`.

# %%
stock_x = {} #independent variables DataFrame hashed by stock
stock_y = {} #dependent variable Series hashed by stock

# %%
for stock in names:
    #calculate and assign technical indicators for each stock
    get_obv(stock)
    get_bollinger(stock)
    get_macd(stock)
    get_vwap(stock)
    get_rsi(stock)
    get_mfi(stock)
    
    #get indepdendent variables
    x = stocks[stock][['OBV_indicator','Bollinger_indicator',
                    'MACD_indicator', 'VWAP_indicator',
                    'RSI_indicator', 'MFI_indicator'
                  ]]

    #get dependent variable
    y = stocks[stock]['buy_indicator']
    
    x = x.dropna()
    y = y[1:]

    #assign the independent and dependent variable to the dictionary
    stock_x[stock] = x
    stock_y[stock] = y

# %% [markdown]
# <h1> Build Training/Testing Sets and Models </h1>

# %% [markdown]
# We will train our model using sklearn's linear regression with stochastic gradient descent, random forest, and neural network models. We also utilized a grid search for our random forest and neural network hyperparameters, which has been commented out.

# %%
sgd_models = {} #SGD models and train/test sets by hashed stock
rf_models = {} #Random forest models and train/test sets hashed by stock
nn_models = {} #Neural Network models and train/test sets hashed by stock

# %%
def build_sgd_model(s):
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import SGDClassifier
    
    X = stock_x[s]
    Y = stock_y[s]

    #Get x_train, x_test, y_train, y_test
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.7, random_state=42)

    clf = SGDClassifier(random_state=42,max_iter=1000,loss="log") 
    clf.fit(x_train,y_train) 

    #save the fitted model and train/test split in the dictionary
    sgd_models[s] = [clf, x_train, x_test, y_train, y_test]

# %%
#Grid Search for Optimal Random Forest Hyperparameters

# from sklearn.model_selection import GridSearchCV
# parameters = { #Parameters are for the random forest classifier model
#      'n_estimators':(10, 20), #the number of trees
#      'max_depth':(6,10), #The maximum depth of any tree
#      'min_samples_split': (10,), #The minimum samples in a node for a split to occur
#      'min_samples_leaf': (8,), #The minimum samples in a leaf node (nodes with fewer samples will be discarded)
# }

# #For grid search, we'll use 3 fold CV, and use all available processors in parallel (n_jobs=-1)
# gs_clf = GridSearchCV(RandomForestClassifier(),parameters,cv=3,n_jobs=-1)
# gs_clf.fit(x_train, np.ravel(y_train))
# gs_clf.best_score_, gs_clf.best_params_ #Best score is the mean CV score of the best estimator (model)

# %%
#Hyperparameter Choice from Grid Search

# (0.7369175627240144,
#  {'max_depth': 10,
#   'min_samples_leaf': 8,
#   'min_samples_split': 10,
#   'n_estimators': 10})

# %%
def build_random_forest_model(s):
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestClassifier
    
    X = stock_x[s]
    Y = stock_y[s]

    #Get x_train, x_test, y_train, y_test
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.7, random_state=42)
    
    
    rf = RandomForestClassifier(random_state=42,n_estimators=10,max_depth=10,min_samples_leaf=8,min_samples_split=10)
    rf.fit(x_train,y_train.astype(int))
    
    #save the fitted model and train/test split in the dictionary
    rf_models[s] = [rf, x_train, x_test, y_train, y_test]

# %%
# #running the grid search code from class:

# from sklearn.model_selection import GridSearchCV
# parameters = {
#     'learning_rate':["constant", "invscaling", "adaptive"],
#     'solver' :('adam',),
#     'activation': ('tanh','relu'),
#     'hidden_layer_sizes': ((30,),(40,),(60,)),
# }
#  #'solver': ('sgd','lbfgs','adam'),

# gs = GridSearchCV(estimator = MLPClassifier(random_state=42,max_iter=2000), param_grid=parameters,cv=5)
# gs.fit(x, y)
# print(gs.best_score_)
# print(gs.best_params_)

# %%
#Hyperparameter Choice from Grid Search

# (0.5801512713228194,
# {'activation': 'relu', 'hidden_layer_sizes': (40,), 'learning_rate': 'constant', 'solver': 'adam'})

# %%
def build_neural_network_model(s):
    from sklearn.model_selection import train_test_split
    from sklearn.neural_network import MLPClassifier

    X = stock_x[s]
    Y = stock_y[s]

    #Get x_train, x_test, y_train, y_test
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.7, random_state=42)
    
    nn = MLPClassifier(solver="adam",hidden_layer_sizes=(40,), max_iter = 2000, 
                    activation='relu',
                    learning_rate='constant',random_state=42
                   )
    nn.fit(x_train,y_train)

    #save the fitted model and train/test split in the dictionary
    nn_models[s] = [nn, x_train, x_test, y_train, y_test]

# %%
#build each model for each stock
for stock in names:
    build_sgd_model(stock)
    build_random_forest_model(stock)
    build_neural_network_model(stock)

# %% [markdown]
# <h1> Run Models and Obtain Results </h1>

# %% [markdown]
# We can now run our saved model on the testing set and save the results in a DataFrame. A generic `run_model(model_info)` function is used that can use the model list created in previous the model building step.

# %%
#create results DataFrame
col_names = ["Training Accuracy", "Testing Accuracy", "Precision", "Recall", "F1 Score", "AUC", "AP"]
stock_names = names
model_names = ["SGD Classifier", "Random Forest", "Neural Network"]
#use pandas MultiIndex to build leveled columns
multi_index=pd.MultiIndex.from_product([stock_names, model_names],
                           names=['Stock', 'Model'])
results_df = pd.DataFrame(np.zeros((len(multi_index),len(col_names))))
results_df.index = multi_index
results_df.columns = col_names

# %%
def run_model(model_info):
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import f1_score,recall_score,precision_score
    from sklearn.metrics import average_precision_score,roc_auc_score
    
    model, x_train, x_test, y_train, y_test = model_info
    
    #get predictions on testing data
    predictions = model.predict(x_test)

    #get metrics
    cfm = confusion_matrix(y_test,predictions)
    accuracy_training = model.score(x_train,y_train)
    accuracy_testing = model.score(x_test,y_test)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    f1 = f1_score(y_test, predictions)
    y_prob = model.predict_proba(x_test)[:,1]
    auc = roc_auc_score(y_test, y_prob)
    ap = average_precision_score(y_test, predictions)
    
    metrics = [accuracy_training, accuracy_testing, precision, recall, f1, auc, ap]
    
    return metrics

# %%
def stock_results(s):
    sgd_res = run_model(sgd_models[s])
    rf_res = run_model(rf_models[s])
    nn_res = run_model(nn_models[s])
    
    #place results in DataFrame by stock
    results_df.loc[[s], :] = np.stack((sgd_res, rf_res, nn_res))

# %%
#get results for each model on each stock
for stock in names:
    stock_results(stock)

# %%
results_df
# Out:
#                       Training Accuracy  Testing Accuracy  Precision  \
# Stock Model
# META  SGD Classifier           0.807168          0.807692   0.464115
#       Random Forest            0.825329          0.828874   0.585185
#       Neural Network           0.824373          0.828874   0.586466
# GOOG  SGD Classifier           0.813859          0.807135   0.378698
#       Random Forest            0.844922          0.842252   0.591667
#       Neural Network           0.844205          0.853400   0.631250
# AMZN  SGD Classifier           0.590920          0.607581   0.542921
#       Random Forest            0.607885          0.610368   0.556474
#       Neural Network           0.602389          0.617057   0.567143
# NFLX  SGD Classifier           0.566308          0.569677   0.470856
#       Random Forest            0.633214          0.640468   0.550725
#       Neural Network           0.632975          0.639353   0.548644
# TSLA  SGD Classifier           0.752210          0.760312   0.485623
#       Random Forest            0.783513          0.780379   0.549451
#       Neural Network           0.785424          0.783166   0.550633
#
#                         Recall  F1 Score       AUC        AP
# Stock Model
# META  SGD Classifier  0.293939  0.359926  0.798300  0.266299
#       Random Forest   0.239394  0.339785  0.851632  0.280001
#       Neural Network  0.236364  0.336933  0.851543  0.279088
# GOOG  SGD Classifier  0.209836  0.270042  0.783107  0.213801
#       Random Forest   0.232787  0.334118  0.829312  0.268167
#       Neural Network  0.331148  0.434409  0.832893  0.322749
# AMZN  SGD Classifier  0.623560  0.580453  0.639364  0.502423
#       Random Forest   0.517286  0.536165  0.636067  0.498001
#       Neural Network  0.508323  0.536124  0.641116  0.502338
# NFLX  SGD Classifier  0.730226  0.572536  0.626172  0.450297
#       Random Forest   0.483051  0.514673  0.655579  0.470041
#       Neural Network  0.485876  0.515356  0.656088  0.469472
# TSLA  SGD Classifier  0.361045  0.414169  0.781850  0.325276
#       Random Forest   0.356295  0.432277  0.824330  0.346825
#       Neural Network  0.413302  0.472185  0.824513  0.365259

# %% [markdown]
# <h1> Visualize Results </h1>

# %% [markdown]
# We can visualize the results DataFrame by metric. We consider the training/testing accuracy, F1 score, and AUC as key metrics for each of the stocks.

# %%
#Training Accuracy

plot_df=results_df.loc[:, ["Training Accuracy"]].reset_index()
labels = names
sgd_vals = plot_df.loc[plot_df.Model=="SGD Classifier", "Training Accuracy"].values
rf_vals = plot_df.loc[plot_df.Model=="Random Forest", "Training Accuracy"].values
nn_vals = plot_df.loc[plot_df.Model=="Neural Network", "Training Accuracy"].values

x = np.arange(0, 1.5*len(labels), 1.5)  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sgd_vals, width, label='SGD Classifier')
rects2 = ax.bar(x, rf_vals, width, label='Random Forest')
rects3 = ax.bar(x + width, nn_vals, width, label='Neural Network')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Training Accuracy")
ax.set_title('Training Accuracy By Model and Stock')
ax.set_xticks(x, labels)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
#Testing Accuracy

plot_df=results_df.loc[:, ["Testing Accuracy"]].reset_index()
labels = names
sgd_vals = plot_df.loc[plot_df.Model=="SGD Classifier", "Testing Accuracy"].values
rf_vals = plot_df.loc[plot_df.Model=="Random Forest", "Testing Accuracy"].values
nn_vals = plot_df.loc[plot_df.Model=="Neural Network", "Testing Accuracy"].values

x = np.arange(0, 1.5*len(labels), 1.5)  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sgd_vals, width, label='SGD Classifier')
rects2 = ax.bar(x, rf_vals, width, label='Random Forest')
rects3 = ax.bar(x + width, nn_vals, width, label='Neural Network')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Testing Accuracy')
ax.set_title('Testing Accuracy By Model and Stock')
ax.set_xticks(x, labels)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# Encouraging results! The training and testing accuracies are generally high, and the larger the training dataset the more accurate our results. The accuracies are pretty consistent along the model across each stock.

# %%
#F1 Score

plot_df=results_df.loc[:, ["F1 Score"]].reset_index()
labels = names
sgd_vals = plot_df.loc[plot_df.Model=="SGD Classifier", "F1 Score"].values
rf_vals = plot_df.loc[plot_df.Model=="Random Forest", "F1 Score"].values
nn_vals = plot_df.loc[plot_df.Model=="Neural Network", "F1 Score"].values

x = np.arange(0, 1.5*len(labels), 1.5)  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sgd_vals, width, label='SGD Classifier')
rects2 = ax.bar(x, rf_vals, width, label='Random Forest')
rects3 = ax.bar(x + width, nn_vals, width, label='Neural Network')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1 Score')
ax.set_title('F1 Score By Model and Stock')
ax.set_xticks(x, labels)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# The F1 scores vary more across the models. We can investigate this deeper by observing the overall average over all stocks and all models.

# %%
f1_vals = results_df.loc[:, ["F1 Score"]]
f1_vals.mean()[0], f1_vals.var()[0] #mean and average
# Out:
# (0.4432765705443808, 0.009703016947662225)

# %% [markdown]
# The F1 score is around 0.4, which means there is more room for improvement to handle the precision-recall tradeoff.

# %%
#AUC

plot_df=results_df.loc[:, ["AUC"]].reset_index()
labels = names
sgd_vals = plot_df.loc[plot_df.Model=="SGD Classifier", "AUC"].values
rf_vals = plot_df.loc[plot_df.Model=="Random Forest", "AUC"].values
nn_vals = plot_df.loc[plot_df.Model=="Neural Network", "AUC"].values

x = np.arange(0, 1.5*len(labels), 1.5)  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sgd_vals, width, label='SGD Classifier')
rects2 = ax.bar(x, rf_vals, width, label='Random Forest')
rects3 = ax.bar(x + width, nn_vals, width, label='Neural Network')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('AUC')
ax.set_title('AUC By Model and Stock')
ax.set_xticks(x, labels)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# The AUC number are quite high, which signifies a strong model! The model performs better than choosing to BUY randomly as all the stocks and individual models have an AUC over 0.5.

# %% [markdown]
# <h1> Feature Importance </h1>

# %% [markdown]
# We can now use a basic random forest model to get a general idea of which technical indicators are more important features for the machine learning model for each stock. The more important features may indicate technical indicators that are better suited to that stock to make the day-trading BUY or NOT BUY strategy.

# %%
names
# Out:
# ['META', 'GOOG', 'AMZN', 'NFLX', 'TSLA']

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model_beta = RandomForestRegressor(max_depth=5) # a basic random forest

tech_indicators = np.array(["OBV", "Bollinger", "MACD", "VWAP", "RSI", "MFI"])

stock_featimp = {} #save the feature importances and sorted order hashed by stock

for stock in names:
    
    print(stock + ":")
    
    x_train, x_test, y_train, y_test  = rf_models[stock][1:]
    
    rf_model_beta.fit(x_train,y_train)    
    importances = rf_model_beta.feature_importances_
    sorted_indices = np.argsort(importances)[::-1]
    feat_labels = tech_indicators

    #print the most important features
    for f in range(len(tech_indicators)):
        print("%2d) %-*s %f" % (f + 1, 30,
                                feat_labels[sorted_indices[f]],
                                importances[sorted_indices[f]]))
    print()

    stock_featimp[stock] = [importances, sorted_indices]
# Out:
# META:
#  1) Bollinger                      0.571321
#  2) MACD                           0.201118
#  3) OBV                            0.129807
#  4) RSI                            0.043638
#  5) VWAP                           0.037520
#  6) MFI                            0.016595
#
# GOOG:
#  1) VWAP                           0.475209
#  2) OBV                            0.190005
#  3) MFI                            0.172191
#  4) RSI                            0.062018
#  5) Bollinger                      0.054905
#  6) MACD                           0.045673
#
# AMZN:
#  1) OBV                            0.467028
#  2) Bollinger                      0.169998
#  3) RSI                            0.168931
#  4) MACD                           0.079105
#  5) VWAP                           0.069852
#  6) MFI                            0.045087
#
# NFLX:
#  1) OBV                            0.363396
#  2) MACD                           0.225979
#  3) Bollinger                      0.217776
#  4) VWAP                           0.087569
#  5) RSI                            0.084875
#  6) MFI                            0.020405
#
# TSLA:
#  1) Bollinger                      0.504114
#  2) MACD                           0.211016
#  3) OBV                            0.160497
#  4) VWAP                           0.056910
#  5) RSI                            0.048981
#  6) MFI                            0.018481

# %%
#visualize the most important features

import matplotlib.pyplot as plt

colors = ["blue", "green", "orange", "red", "gray"]

fig, ax = plt.subplots(5)
fig.suptitle("Feature Importances By Stock")

fig.subplots_adjust(bottom=-2.5, right=0.8)

i=0
for stock in names:
    
    ax[i].set_title(stock)
    
    this_importance = stock_featimp[stock][0]
    this_sorted = stock_featimp[stock][1]
    this_sorted = np.flip(np.array(this_sorted))
        
    ax[i].barh(range(len(tech_indicators)), this_importance[this_sorted], align='center', color = colors[i])
    ax[i].set_yticks(range(len(tech_indicators)), tech_indicators[this_sorted])
        
    i+=1

plt.show()

# %% [markdown]
# The most important features for each stock differ, with one technical indicator usually being much more significant than the others. However, for the overall portfolio of five stocks, the Bollinger Bands, MACD, and OBV technical indicators are generally prominent.
